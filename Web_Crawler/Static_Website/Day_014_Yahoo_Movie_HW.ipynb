# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'html5lib')
html = soup.find("select", attrs={'name':'movie_id'})
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})

for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# Movie: 永不放棄：詹姆斯艾利森, ID: 10652
# Movie: 雙面遊戲, ID: 10642
# Movie: 巴黎寂寞不打烊, ID: 10636
# Movie: 惡夜救援, ID: 10634
# Movie: 響HIBIKI, ID: 10627
# Movie: 全境入侵, ID: 10625
# Movie: 你的鳥兒會唱歌, ID: 10618
# Movie: 怨鈴, ID: 10604
# Movie: 謊畫情人, ID: 10577
# Movie: 靠北少女, ID: 10575
# Movie: 在你身邊, ID: 10567
# Movie: 說再見前的30分鐘, ID: 10561
# Movie: 1/2的魔法, ID: 10505
# Movie: 靈異405號房, ID: 10687
# Movie: 在黑暗中漫舞：20週年數位修復版, ID: 10678
# Movie: 葉問4：完結篇, ID: 10675
# Movie: 來自深淵 深沉靈魂的黎明  4DX/MX4D, ID: 10658
# Movie: 天氣之子, ID: 10645
# Movie: 喪屍來鬥陣, ID: 10644
# Movie: 末代皇帝, ID: 10640
# Movie: 白髮魔女傳, ID: 10639
# Movie: 誰殺了唐吉訶德, ID: 10624
# Movie: 奇蹟救援, ID: 10605
# Movie: 奪命隧道, ID: 10599
# Movie: 海邊走走, ID: 10495
# Movie: 閉嘴！彈琴, ID: 10631
# Movie: 素人特工, ID: 10622
# Movie: 劇場版白箱, ID: 10621
# Movie: 老娘就要這麼活, ID: 10611
# Movie: 初戀, ID: 10607
# Movie: 黑暗戰域, ID: 10606
# Movie: 陪你玩最大, ID: 10602
# Movie: 觸不到的愛, ID: 10598
# Movie: 金都, ID: 10530
# Movie: 現屍報, ID: 10619
# Movie: 壞教育, ID: 10617
# Movie: 鎖命佈局, ID: 10616
# Movie: 正在相愛嗎？, ID: 10615
# Movie: 見鬼的戀愛季節, ID: 10612
# Movie: 抽屍剝繭, ID: 10591
# Movie: 流感, ID: 10583
# Movie: 假面騎士令和時代的開端, ID: 10632
# Movie: 無聲革命, ID: 10601
# Movie: 惡之華, ID: 10587
# Movie: 蜈蚣降, ID: 10586
# Movie: 數碼寶貝 LAST EVOLUTION 絆, ID: 10572
# Movie: 吞噬, ID: 10560
# Movie: 美好拾光公司, ID: 10541
# Movie: 緣來想見妳, ID: 10529
# Movie: 搭火車旅行好吃驚, ID: 10492
# Movie: 戀愛倒帶中, ID: 10589
# Movie: 罪：米開朗基羅, ID: 10574
# Movie: 知道天空有多藍的人啊, ID: 10526
# Movie: 築夢奇蹟, ID: 10511
# Movie: 末日異戰, ID: 10402
# Movie: 樂來越愛你, ID: 10609
# Movie: 搞鬼, ID: 10570
# Movie: 犬鳴村, ID: 10543
# Movie: 間諜速成班, ID: 10538
# Movie: 我的英雄學院劇場版：英雄新世紀, ID: 10481
# Movie: 魔髮精靈唱遊世界, ID: 10466
# Movie: 我的學生都是配樂大師, ID: 10557
# Movie: 抓住救命稻草的野獸們, ID: 10507
# Movie: 第六感生死戀, ID: 10504
# Movie: Re從零開始的異世界生活 外傳集, ID: 10480
# Movie: 記憶屋, ID: 10470
# Movie: 我出去醫下, ID: 10494
# Movie: 刺激1995, ID: 10518
# Movie: 安雅的回家路, ID: 10516
# Movie: 劇場版 不起眼女主角培育法 Fine, ID: 10486
# Movie: 血衛, ID: 10469
# Movie: 狂飆一夢, ID: 10506
# Movie: 大畫特務, ID: 10478
# Movie: 明明會說話, ID: 10440
# Movie: 艾瑪, ID: 10396
# Movie: 哥布林殺手 劇場版, ID: 10438
# Movie: 女鬼橋, ID: 10437
# Movie: 極地守護犬, ID: 10383
# Movie: 隱形人, ID: 10359
# Movie: 李察朱威爾事件, ID: 10368
# Movie: 音速小子, ID: 9246
# Movie: 逃出夢幻島, ID: 10485
# Movie: 全境失控, ID: 10426
# Movie: 愛情人形, ID: 10394
# Movie: 猛禽小隊：小丑女大解放, ID: 10268
# Movie: 1917, ID: 10189
# Movie: 你的情歌, ID: 10407
# Movie: 巧虎電影：英雄遊樂園, ID: 10429
# Movie: 不完美的正義, ID: 10243
# Movie: 星星知我心, ID: 10409
# Movie: 驅魔直播, ID: 10375
# Movie: 那一夜, ID: 10345
# Movie: BanG Dream！ FILM LIVE, ID: 10271
# Movie: Hello World, ID: 10302
# Movie: 為美好的世界獻上祝福！紅傳說, ID: 10226
# Movie: 青春豬頭少年不會夢到懷夢美少女, ID: 10146
# Movie: 玩命關頭：特別行動, ID: 9582
# Movie: 電影　刀劍亂舞, ID: 9817
# Movie: 大象席地而坐, ID: 9236
# Movie: 夏目友人帳劇場版：緣結空蟬, ID: 8801
# Movie: 魔女首部曲：誕生, ID: 8817
# Movie: 不可能的任務：全面瓦解, ID: 7767
# Movie: 遊戲人生Zero, ID: 7546
# Movie: 艾蜜莉的異想世界：修復版, ID: 6993
# Movie: 一一, ID: 6963
# Movie: 魔導少年龍之淚, ID: 6884
# Movie: 祝你有個甜美的夢, ID: 6933
# Movie: 刀劍神域劇場版－序列爭戰, ID: 6600
# Movie: 碧海藍天, ID: 6417
# Movie: 關不住的誘惑, ID: 6398
# Movie: 紅色情深 經典數位修復, ID: 6307
# Movie: 白色情迷 經典數位修復, ID: 6306
# Movie: 藍色情挑 經典數位修復, ID: 6302
# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10495

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
#print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'html5lib')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 五月 24
# 五月 25
# 五月 26
# 五月 27
# 五月 28

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-05-24"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'html5lib')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
# Out:
# <div class="pc-movie-schedule-form">
#     <div class="area_timebox">
#    <div class="area_title">台北市</div>
#       <ul id="theater_id_29" class="area_time _c jq_area_time" data-theater_name="國賓影城(台北長春廣場)" data-theater_url="http://www.ambassador.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=29" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=29">國賓影城(台北長春廣場)</a>
#            <span>02-25155755</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="73592636" class="gabtn"
#                         value="2020-05-24 13:10:00" data-movie_type="數位"
#                         data-movie_title="海邊走走"
#                         data-movie_date="05.24"
#                         data-movie_time="13:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海邊走走']" data-news="news"
#                         />
#                     <label for="73592636" class="">13:10</label>
#                                                                     <input type="radio" name="schedule_list" id="73592637" class="gabtn"
#                         value="2020-05-24 15:05:00" data-movie_type="數位"
#                         data-movie_title="海邊走走"
#                         data-movie_date="05.24"
#                         data-movie_time="15:05"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海邊走走']" data-news="news"
#                         />
#                     <label for="73592637" class="select">15:05</label>
#                                                                     <input type="radio" name="schedule_list" id="73592638" class="gabtn"
#                         value="2020-05-24 19:00:00" data-movie_type="數位"
#                         data-movie_title="海邊走走"
#                         data-movie_date="05.24"
#                         data-movie_time="19:00"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海邊走走']" data-news="news"
#                         />
#                     <label for="73592638" class="select">19:00</label>
#                                                                     <input type="radio" name="schedule_list" id="73592639" class="gabtn"
#                         value="2020-05-24 21:00:00" data-movie_type="數位"
#                         data-movie_title="海邊走走"
#                         data-movie_date="05.24"
#                         data-movie_time="21:00"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海邊走走']" data-news="news"
#                         />
#                     <label for="73592639" class="select">21:00</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_31" class="area_time _c jq_area_time" data-theater_name="光點台北電影主題館" data-theater_url="http://www.spot.org.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=31" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=31">光點台北電影主題館</a>
#            <span>02-25117786</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                    <input type="radio" name="schedule_list" id="73592710" class="gabtn"
#                         value="2020-05-24 12:50:00" data-movie_type="數位"
#                         data-movie_title="海邊走走"
#                         data-movie_date="05.24"
#                         data-movie_time="12:50"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海邊走走']" data-news="news"
#                         />
#                     <label for="73592710" class="">12:50</label>
#                                                                     <input type="radio" name="schedule_list" id="73592711" class="gabtn"
#                         value="2020-05-24 16:55:00" data-movie_type="數位"
#                         data-movie_title="海邊走走"
#                         data-movie_date="05.24"
#                         data-movie_time="16:55"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海邊走走']" data-news="news"
#                         />
#                     <label for="73592711" class="select">16:55</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_41" class="area_time _c jq_area_time" data-theater_name="台北真善美劇院" data-theater_url="" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=41" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=41">台北真善美劇院</a>
#            <span>02-23312270</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="73576069" class="gabtn"
#                         value="2020-05-24 16:50:00"  data-movie="f326671fda6344ffa710fa0b49126b84"
#                         data-cinema="f644412efbb811e58858f2128151146f" data-session="db250485ef234983a7c10688209fa209"
#                         data-date="1590249600" data-time="1590310200"
#                         data-movie_type="數位"
#                         data-movie_title="海邊走走"
#                         data-movie_date="05.24"
#                         data-movie_time="16:50"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海邊走走']" data-ezding="ezding"
#                         />
#                     <label for="73576069" class="select">16:50</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_45" class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_url="http://www.vscinemas.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">台北信義威秀影城</a>
#            <span>02-87805566</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="73582595" class="gabtn"
#                         value="2020-05-24 18:10:00"  data-movie="735b20948ecf401784c7b20a22efce42"
#                         data-cinema="40288eb0050f542401050f554e7e0674" data-session="870033d0d1ad4cb38d7de4c28bd976f7"
#                         data-date="1590249600" data-time="1590315000"
#                         data-movie_type="數位"
#                         data-movie_title="海邊走走"
#                         data-movie_date="05.24"
#                         data-movie_time="18:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海邊走走']" data-ezding="ezding"
#                         />
#                     <label for="73582595" class="select">18:10</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_186" class="area_time _c jq_area_time" data-theater_name="喜樂時代影城南港店" data-theater_url="http://www.centuryasia.com.tw/default.aspx" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=186" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=186">喜樂時代影城南港店</a>
#            <span>02-27888185</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="73586943" class="gabtn"
#                         value="2020-05-24 15:10:00"  data-movie="e8b036dff0d24c0b99a8c15432ecb901"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="2a8ade201c094fdda2c2b348366b5644"
#                         data-date="1590249600" data-time="1590304200"
#                         data-movie_type="數位"
#                         data-movie_title="海邊走走"
#                         data-movie_date="05.24"
#                         data-movie_time="15:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海邊走走']" data-ezding="ezding"
#                         />
#                     <label for="73586943" class="select">15:10</label>
#                                                                                     <input type="radio" name="schedule_list" id="73586944" class="gabtn"
#                         value="2020-05-24 17:10:00"  data-movie="e8b036dff0d24c0b99a8c15432ecb901"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="f36fd14a284d49b58134a8d12ba213e1"
#                         data-date="1590249600" data-time="1590311400"
#                         data-movie_type="數位"
#                         data-movie_title="海邊走走"
#                         data-movie_date="05.24"
#                         data-movie_time="17:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海邊走走']" data-ezding="ezding"
#                         />
#                     <label for="73586944" class="select">17:10</label>
#                                                                                     <input type="radio" name="schedule_list" id="73586945" class="gabtn"
#                         value="2020-05-24 19:10:00"  data-movie="e8b036dff0d24c0b99a8c15432ecb901"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="b4f392dabf37457d8c0bbb054d78191e"
#                         data-date="1590249600" data-time="1590318600"
#                         data-movie_type="數位"
#                         data-movie_title="海邊走走"
#                         data-movie_date="05.24"
#                         data-movie_time="19:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '海邊走走']" data-ezding="ezding"
#                         />
#                     <label for="73586945" class="select">19:10</label>
#                                                </div>
#            </li>
#           </ul>
#    </div>
#
#     <div class="booking_modal jq_booking_modal">
#     <div class="booking_modal_backdrop"></div>
#     <!-- 時報訂票 ＆ 有官網訂票 新增 class => no_seats -->
#     <div class="booking_modal_content jq_booking_modal_content">
#         <form method="get" action="https://movies.yahoo.com.tw/ticket/ezding_ticket" target="_blank" id="form_schedule">
#                 <div class="ezding_ticket_value">
#             <input type="hidden" name="movie_id" value="">
#             <input type="hidden" name="cinema_id" value="">
#             <input type="hidden" name="session_id" value="">
#             <input type="hidden" name="date" value="">
#             <input type="hidden" name="time" value="">
#             <input type="hidden" name="campaign_code" value="yahoopc">
#         </div>
#         <ul class="top_infos">
#             <li>
#                 <p>片名</p>
#                 <h3 id="top_infos_movie"></h3>
#             </li>
#             <li>
#                 <p>影城</p>
#                 <h3 id="top_infos_theater"></h3>
#             </li>
#             <li>
#                 <p>日期</p>
#                 <h3 id="top_infos_date"></h3>
#             </li>
#             <li>
#                 <p>版本</p>
#                 <h3 id="top_infos_movie_type"></h3>
#             </li>
#             <li>
#                 <p>時間</p>
#                 <h3 id="top_infos_time"></h3>
#             </li>
#         </ul>
#
#         <div class="booking_seats">
#             <a href="#" class="theater_schedules gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_全部電影場次', '']">全部電影場次</a>
#             <a href="#" class="theater_url gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_官網訂票', '']" target="_blank">官網訂票</a>
#             <p id="no_theater_url" class="no_theater_url">無提供官網訂票</p>
#
#             <p id="booking_number" class="booking_number">人數</p>
#             <div class="booking_seat_group jq_booking_seat_group">
#                                     <input type="radio" name="tickets" id="seat_1" value="1" />
#                     <label for="seat_1">1</label>
#                                     <input type="radio" name="tickets" id="seat_2" value="2"  checked />
#                     <label for="seat_2">2</label>
#                                     <input type="radio" name="tickets" id="seat_3" value="3" />
#                     <label for="seat_3">3</label>
#                                     <input type="radio" name="tickets" id="seat_4" value="4" />
#                     <label for="seat_4">4</label>
#                                     <input type="radio" name="tickets" id="seat_5" value="5" />
#                     <label for="seat_5">5</label>
#                                     <input type="radio" name="tickets" id="seat_6" value="6" />
#                     <label for="seat_6">6</label>
#                             </div>
#             <button type="submit" class="action_btn action_booking_btn jq_booking_btn gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_選位', '']">選位</button>
#             <a href="#" class="action_btn action_link jq_booking_link gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_時報戲院_官網選位', '']" target="_blank">官網訂票</a>
#             <button type="button" class="action_btn close jq_close_booking_btn">關閉</button>
#         </div>
#         </form>
#
#         <!-- 無官網訂票區塊 -->
#         <div class="no_theater_section">
#             <p>無提供官網訂票</p>
#             <button type="button" class="action_btn close jq_close_booking_btn">關閉</button>
#         </div>
#     </div>
# </div></div>

# %%
print('-------------------------------------------')
for ul in html:
    print(f"電影院: {ul['data-theater_name'].strip()}")
    print(f"放映類型: {ul.find('li', 'taps').text.strip()}")
    for time in ul.find_all('input', 'gabtn'):
        print(time['value'].strip())
    
    print('-------------------------------------------')
# Out:
# -------------------------------------------
# 電影院: 國賓影城(台北長春廣場)
# 放映類型: 數位
# 2020-05-24 13:10:00
# 2020-05-24 15:05:00
# 2020-05-24 19:00:00
# 2020-05-24 21:00:00
# -------------------------------------------
# 電影院: 光點台北電影主題館
# 放映類型: 數位
# 2020-05-24 12:50:00
# 2020-05-24 16:55:00
# -------------------------------------------
# 電影院: 台北真善美劇院
# 放映類型: 數位
# 2020-05-24 16:50:00
# -------------------------------------------
# 電影院: 台北信義威秀影城
# 放映類型: 數位
# 2020-05-24 18:10:00
# -------------------------------------------
# 電影院: 喜樂時代影城南港店
# 放映類型: 數位
# 2020-05-24 15:10:00
# 2020-05-24 17:10:00
# 2020-05-24 19:10:00
# -------------------------------------------

# %%
# Out:
# ----------------------------------------------------------------------
# 電影院:  台北美麗華大直影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:10:00
# 2019-08-21 13:15:00
# 2019-08-21 15:20:00
# 2019-08-21 19:30:00
# 2019-08-21 21:40:00
# 2019-08-21 22:30:00
# ----------------------------------------------------------------------
# 電影院:  台北新光影城
# 放映類型:  數位
# 2019-08-21 10:00:00
# 2019-08-21 14:50:00
# 2019-08-21 19:30:00
# ----------------------------------------------------------------------
# 電影院:  台北in89豪華數位影城
# 放映類型:  數位
# 2019-08-21 09:30:00
# 2019-08-21 11:20:00
# 2019-08-21 13:15:00
# 2019-08-21 15:10:00
# 2019-08-21 16:10:00
# 2019-08-21 17:10:00
# 2019-08-21 18:05:00
# 2019-08-21 19:10:00
# 2019-08-21 21:10:00
# 2019-08-21 23:10:00
# 2019-08-22 01:10:00
# ----------------------------------------------------------------------
# 電影院:  台北日新威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 10:55:00
# 2019-08-21 12:50:00
# 2019-08-21 14:45:00
# 2019-08-21 16:40:00
# 2019-08-21 18:35:00
# 2019-08-21 20:35:00
# ----------------------------------------------------------------------
# 電影院:  喜滿客絕色影城
# 放映類型:  數位
# 2019-08-21 10:00:00
# 2019-08-21 11:55:00
# 2019-08-21 13:50:00
# 2019-08-21 15:45:00
# 2019-08-21 17:40:00
# 2019-08-21 19:35:00
# 2019-08-21 21:30:00
# ----------------------------------------------------------------------
# 電影院:  台北信義威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:00:00
# 2019-08-21 13:00:00
# 2019-08-21 15:00:00
# 2019-08-21 17:00:00
# 2019-08-21 19:00:00
# 2019-08-21 21:00:00
# 2019-08-21 23:00:00
# ----------------------------------------------------------------------
# 電影院:  喜滿客京華影城
# 放映類型:  數位
# 2019-08-21 10:30:00
# 2019-08-21 12:30:00
# 2019-08-21 14:30:00
# 2019-08-21 16:30:00
# 2019-08-21 18:30:00
# 2019-08-21 20:30:00
# 2019-08-21 22:30:00
# ----------------------------------------------------------------------
# 電影院:  京站威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:00:00
# 2019-08-21 13:00:00
# 2019-08-21 15:00:00
# 2019-08-21 17:00:00
# 2019-08-21 19:00:00
# 2019-08-21 21:00:00
# ----------------------------------------------------------------------
# 電影院:  喜樂時代影城南港店
# 放映類型:  數位
# 2019-08-21 10:20:00
# 2019-08-21 11:10:00
# 2019-08-21 12:20:00
# 2019-08-21 13:10:00
# 2019-08-21 14:20:00
# 2019-08-21 15:10:00
# 2019-08-21 16:20:00
# 2019-08-21 17:10:00
# 2019-08-21 18:20:00
# 2019-08-21 19:15:00
# 2019-08-21 20:20:00
# 2019-08-21 21:15:00
# 2019-08-21 22:20:00
